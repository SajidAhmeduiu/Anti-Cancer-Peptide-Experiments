# %%
from keras.layers import Dense
# Out:
# Using TensorFlow backend.

# %%
from keras import backend as K
K.tensorflow_backend._get_available_gpus()
# Out:
# ['/job:localhost/replica:0/task:0/device:GPU:0']

# %%
from tensorflow.python.client import device_lib

print(device_lib.list_local_devices())
# Out:
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 18021701030220510571
# , name: "/device:XLA_CPU:0"
# device_type: "XLA_CPU"
# memory_limit: 17179869184
# locality {
# }
# incarnation: 1195291897962819831
# physical_device_desc: "device: XLA_CPU device"
# , name: "/device:XLA_GPU:0"
# device_type: "XLA_GPU"
# memory_limit: 17179869184
# locality {
# }
# incarnation: 9973716629792311802
# physical_device_desc: "device: XLA_GPU device"
# , name: "/device:GPU:0"
# device_type: "GPU"
# memory_limit: 11992678400
# locality {
#   bus_id: 1
#   links {
#   }
# }
# incarnation: 17767156159979929045
# physical_device_desc: "device: 0, name: TITAN Xp, pci bus id: 0000:01:00.0, compute capability: 6.1"
# ]

# %%
import pandas as pd
import numpy as np

# %%
hydrophobicities = pd.read_excel('10_hydrophobicities.xlsx')
hydrophobicities.head()
# Out:
#    Residue Type  kdHydrophobicity         ...           wolfendenHydrophobicity  argosHydrophobicity
# 6           Ala               1.8         ...                              1.12                 0.61
# 19          Arg              -4.5         ...                             -2.55                 0.60
# 17          Asn              -3.5         ...                             -0.83                 0.06
# 16          Asp              -3.5         ...                             -0.83                 0.46
# 4           Cys               2.5         ...                              0.59                 1.07
#
# [5 rows x 12 columns]

# %%
hydrophobicities_dict = hydrophobicities.to_dict(orient='list')
hydrophobicities_dict
# Out:
# {'Residue Type': ['Ala',
#   'Arg',
#   'Asn',
#   'Asp',
#   'Cys',
#   'Gln',
#   'Glu',
#   'Gly',
#   'His',
#   'Ile',
#   'Leu',
#   'Lys',
#   'Met',
#   'Phe',
#   'Pro',
#   'Ser',
#   'Thr',
#   'Trp',
#   'Tyr',
#   'Val'],
#  'kdHydrophobicity': [1.8,
#   -4.5,
#   -3.5,
#   -3.5,
#   2.5,
#   -3.5,
#   -3.5,
#   -0.4,
#   -3.2,
#   4.5,
#   3.8,
#   -3.9,
#   1.9,
#   2.8,
#   -1.6,
#   -0.8,
#   -0.7,
#   -0.9,
#   -1.3,
#   4.2],
#  'wwHydrophobicity': [-0.17,
#   -0.81,
#   -0.42,
#   -1.23,
#   0.24,
#   -0.58,
#   -2.02,
#   -0.01,
#   -0.96,
#   0.31,
#   0.56,
#   -0.99,
#   0.23,
#   1.13,
#   -0.45,
#   -0.13,
#   -0.14,
#   1.85,
#   0.94,
#   -0.07],
#  'hhHydrophobicity': [0.11,
#   2.58,
#   2.05,
#   3.49,
#   -0.13,
#   2.36,
#   2.68,
#   0.74,
#   2.06,
#   -0.6,
#   -0.55,
#   2.71,
#   -0.1,
#   -0.32,
#   2.23,
#   0.84,
#   0.52,
#   0.3,
#   0.68,
#   -0.31],
#  'mfHydrophobicity': [0.0,
#   3.71,
#   3.47,
#   2.95,
#   0.49,
#   3.01,
#   1.64,
# ...

# %%
hydrophobicities['Residue Type']
# Out:
# 6     Ala
# 19    Arg
# 17    Asn
# 16    Asp
# 4     Cys
# 15    Gln
# 14    Glu
# 7     Gly
# 13    His
# 0     Ile
# 2     Leu
# 18    Lys
# 5     Met
# 3     Phe
# 12    Pro
# 9     Ser
# 8     Thr
# 10    Trp
# 11    Tyr
# 1     Val
# Name: Residue Type, dtype: object

# %%
signatures = pd.Series(['A','R','N','D','C','Q','E','G','H','I','L','K','M','F','P','S','T','W','Y','V'])
hydrophobicities['Residue Signature'] = signatures.values
hydrophobicities['Residue Signature']
# Out:
# 6     A
# 19    R
# 17    N
# 16    D
# 4     C
# 15    Q
# 14    E
# 7     G
# 13    H
# 0     I
# 2     L
# 18    K
# 5     M
# 3     F
# 12    P
# 9     S
# 8     T
# 10    W
# 11    Y
# 1     V
# Name: Residue Signature, dtype: object

# %%
hydrophobicities['Residue Signature']
# Out:
# 6     E
# 19    V
# 17    W
# 16    T
# 4     C
# 15    S
# 14    P
# 7     G
# 13    F
# 0     A
# 2     N
# 18    Y
# 5     Q
# 3     D
# 12    M
# 9     I
# 8     H
# 10    L
# 11    K
# 1     R
# Name: Residue Signature, dtype: object

# %%
residue_types = hydrophobicities['Residue Type']
residue_signature = hydrophobicities['Residue Signature']

for i,j in zip(residue_types,residue_signature) :
    print(i,j)
# Out:
# Ala A
# Arg R
# Asn N
# Asp D
# Cys C
# Gln Q
# Glu E
# Gly G
# His H
# Ile I
# Leu L
# Lys K
# Met M
# Phe F
# Pro P
# Ser S
# Thr T
# Trp W
# Tyr Y
# Val V

# %%
hydrophobicities.to_excel('10_hydrophobicities.xlsx')
